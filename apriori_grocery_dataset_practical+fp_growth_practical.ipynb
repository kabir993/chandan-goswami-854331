# %% [markdown]
# <a href="https://colab.research.google.com/github/kabir993/kabiropedia/blob/main/apriori_grocery_dataset_practical%2Bfp_growth_practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('/content/groceries - groceries.csv')

# %%
dataset.head(3)
# Out:
#    Item(s)          Item 1               Item 2     Item 3       Item 4  \
# 0        4    citrus fruit  semi-finished bread  margarine  ready soups
# 1        3  tropical fruit               yogurt     coffee          NaN
# 2        1      whole milk                  NaN        NaN          NaN
#
#   Item 5 Item 6 Item 7 Item 8 Item 9  ... Item 23 Item 24 Item 25 Item 26  \
# 0    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
#
#   Item 27 Item 28 Item 29 Item 30 Item 31 Item 32
# 0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN
#
# [3 rows x 33 columns]

# %%
dataset.columns
# Out:
# Index(['Item(s)', 'Item 1', 'Item 2', 'Item 3', 'Item 4', 'Item 5', 'Item 6',
#        'Item 7', 'Item 8', 'Item 9', 'Item 10', 'Item 11', 'Item 12',
#        'Item 13', 'Item 14', 'Item 15', 'Item 16', 'Item 17', 'Item 18',
#        'Item 19', 'Item 20', 'Item 21', 'Item 22', 'Item 23', 'Item 24',
#        'Item 25', 'Item 26', 'Item 27', 'Item 28', 'Item 29', 'Item 30',
#        'Item 31', 'Item 32'],
#       dtype='object')

# %%
dataset["Item 1"][0]
# Out:
# 'citrus fruit'

# %%
dataset.shape
# Out:
# (9835, 33)

# %%
Market=[]
for i in range(0,dataset.shape[0]):
    pass
    cus=[]

# %%
dataset["Item 1"][9834]
# Out:
# 'chicken'

# %%
for j in dataset.columns:
    print(dataset[j][i])
    # Use the built-in __class__ attribute to check the type
    if dataset[j][i].__class__ == str:
        cus.append(dataset[j][i])
    Market.append(cus)
# Out:
# 5
# chicken
# tropical fruit
# other vegetables
# vinegar
# shopping bags
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
Market
# Out:
# [['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
#  ['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'],
# ...

# %%
import collections

# %%
l=[]
for i in Market:
    for j in i:
        l.append(j)

# %%
p=collections.Counter(l)

# %%
p.keys()
# Out:
# dict_keys(['chicken', 'tropical fruit', 'other vegetables', 'vinegar', 'shopping bags'])

# %%
p.values()
# Out:
# dict_values([33, 33, 33, 33, 33])

# %%
d={"itemnames":p.keys(),"values":p.values()}

# %%
pd.DataFrame(d).sort_values("values",ascending=False)
# Out:
#           itemnames  values
# 0           chicken      33
# 1    tropical fruit      33
# 2  other vegetables      33
# 3           vinegar      33
# 4     shopping bags      33

# %%
pd.set_option("display.max_rows", 200)

# %%
from mlxtend.preprocessing import TransactionEncoder # This line correctly imports the class
tr = TransactionEncoder() # Use TransactionEncoder with an uppercase 'E' here

# %%
tr.fit(Market)
# Out:
# TransactionEncoder()

# %%
df = pd.DataFrame(tr.transform(Market),columns=tr.columns_)

# %%
df
# Out:
#     chicken  other vegetables  shopping bags  tropical fruit  vinegar
# 0      True              True           True            True     True
# 1      True              True           True            True     True
# 2      True              True           True            True     True
# 3      True              True           True            True     True
# 4      True              True           True            True     True
# 5      True              True           True            True     True
# 6      True              True           True            True     True
# 7      True              True           True            True     True
# 8      True              True           True            True     True
# 9      True              True           True            True     True
# 10     True              True           True            True     True
# 11     True              True           True            True     True
# ...

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support=0.07, use_colnames=True, max_len=3)
frequent_itemsets.sort_values(by='support', ascending=False).head(20)
# Out:
#     support                                           itemsets
# 0       1.0                                          (chicken)
# 13      1.0                           (vinegar, shopping bags)
# 23      1.0        (vinegar, other vegetables, tropical fruit)
# 22      1.0         (vinegar, shopping bags, other vegetables)
# 21      1.0  (shopping bags, other vegetables, tropical fruit)
# 20      1.0                 (chicken, vinegar, tropical fruit)
# 19      1.0                  (chicken, shopping bags, vinegar)
# 18      1.0           (chicken, shopping bags, tropical fruit)
# 17      1.0               (chicken, vinegar, other vegetables)
# 16      1.0        (chicken, other vegetables, tropical fruit)
# 15      1.0         (chicken, shopping bags, other vegetables)
# 14      1.0                          (vinegar, tropical fruit)
# 12      1.0                    (shopping bags, tropical fruit)
# 1       1.0                                 (other vegetables)
# ...

# %%
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mlxtend.frequent_patterns import fpgrowth
fpgrowth(df, min_support=0.07, use_colnames=True, max_len=3).sort_values(by='support')
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support                                           itemsets
# 0       1.0                                          (vinegar)
# 22      1.0           (chicken, shopping bags, tropical fruit)
# 21      1.0  (shopping bags, other vegetables, tropical fruit)
# 20      1.0               (chicken, vinegar, other vegetables)
# 19      1.0                  (chicken, shopping bags, vinegar)
# 18      1.0         (vinegar, shopping bags, other vegetables)
# 17      1.0                 (chicken, vinegar, tropical fruit)
# 16      1.0        (vinegar, other vegetables, tropical fruit)
# ...
