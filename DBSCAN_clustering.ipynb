# %% [markdown]
# <a href="https://colab.research.google.com/github/kabir993/kabiropedia/blob/main/DBSCAN_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y=make_moons(n_samples=250,noise=0.05)

# %%
df = {"data1": x[:, 0], "data2": x[:, 1],}
dataset=pd.DataFrame(df)
dataset.head()
# Out:
#       data1     data2
# 0  0.112590  1.028108
# 1  1.970322  0.353966
# 2 -0.861330  0.381043
# 3 -1.022271  0.109533
# 4  1.401943 -0.428053

# %%
sns.scatterplot(x="data1",y="data2",data=dataset)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db=DBSCAN(eps=0.5,min_samples=5)

# %%
dataset["predict"]=db.fit_predict(dataset)

# %%
sns.scatterplot(x="data1",y="data2",hue="predict",data=dataset)
plt.show()
