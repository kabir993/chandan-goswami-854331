# %% [markdown]
# <a href="https://colab.research.google.com/github/kabir993/kabiropedia/blob/main/svm_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/content/placement.csv')
dataset.head(4)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
sns.scatterplot(x='cgpa',y='package',data=dataset)
plt.show()

# %%
x=dataset[["cgpa"]]
y=dataset["package"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVR
model=SVR(kernel="linear")
model.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
model.score(x_test,y_test)
# Out:
# 0.7706668029575103

# %%
model.score(x_train,y_train)
# Out:
# 0.7745351616879739

# %%
sns.scatterplot(x="cgpa", y="package", data=dataset)
# Plot the predictions, specifying 'color' within plt.plot()
plt.plot(dataset[["cgpa"]], model.predict(x), color="red")
plt.show()
