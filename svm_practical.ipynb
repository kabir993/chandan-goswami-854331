# %% [markdown]
# <a href="https://colab.research.google.com/github/kabir993/kabiropedia/blob/main/svm_practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset=pd.read_csv('/content/placement.csv')
dataset.head(4)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1

# %%
# !pip install mlxtend

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
sns.scatterplot(x='cgpa',y='iq',data=dataset,hue='placement')
plt.show()

# %%
dataset.drop(columns=["Unnamed: 0"],inplace=True)

# %%
x=dataset.iloc[:,:-1]
y=dataset["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC

# %%
sv=SVC(kernel='poly')
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
sv.score(x_test,y_test)
# Out:
# 0.55

# %%
sv.score(x_train,y_train)
# Out:
# 0.55

# %%
plot_decision_regions(x.values,y.values,sv)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
