# %% [markdown]
# <a href="https://colab.research.google.com/github/kabir993/kabiropedia/blob/main/logistic_regression%2Cbinary_classification%2Cmultiple_input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/placement.csv")
dataset.tail(5)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %%
dataset.drop(columns=['Unnamed: 0'], inplace=True)

# %%
dataset.shape
# Out:
# (100, 3)

# %%
sns.scatterplot(x="cgpa", y="iq", data=dataset, hue="placement")
plt.legend(loc=1)
plt.show()

# %%
x=dataset.iloc[:,:-1]

x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
x.ndim
# Out:
# 2

# %%
y=dataset["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 85.0

# %%
lr.predict([[6.4 ,	140]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
pip install mlxtend

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plt.figure(figsize=(7,4))
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=lr)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
lr.coef_
# Out:
# array([[3.08692655, 0.00887102]])

# %%
lr.intercept_
# Out:
# array([-19.61194721])
